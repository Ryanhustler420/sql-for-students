# %%
# %load_ext sql
# %sql postgresql://admin:admin@db:5432/company
# Out:
# Connecting to 'postgresql://admin:***@db:5432/company'

# %%
# %%sql
# SELECT * FROM student;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# 6 rows affected.
# +----+--------+---------------------+-----+------------+
# | id |  name  |        email        | age |    city    |
# +----+--------+---------------------+-----+------------+
# | 2  | Priya  |   priya@yahoo.com   |  30 |   Delhi    |
# | 3  | Gaurav |  gourav@hotmail.com |  25 |  Kolkata   |
# | 1  | Rajesh |   rajesh@gmail.com  |  26 |   Mumbai   |
# | 6  | Simar  | prabsimar@gmail.com |  19 | Jamshedpur |
# | 5  | Ankit  |   ankit@gmail.com   |  27 |  Banglore  |
# | 4  | Saurav |   sourav@gmail.com  |  32 |  Channai   |
# +----+--------+---------------------+-----+------------+

# %%
# %%sql
# ALTER TABLE student
# RENAME COLUMN name to full_name;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from student;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# 6 rows affected.
# +----+-----------+---------------------+-----+------------+
# | id | full_name |        email        | age |    city    |
# +----+-----------+---------------------+-----+------------+
# | 2  |   Priya   |   priya@yahoo.com   |  30 |   Delhi    |
# | 3  |   Gaurav  |  gourav@hotmail.com |  25 |  Kolkata   |
# | 1  |   Rajesh  |   rajesh@gmail.com  |  26 |   Mumbai   |
# | 6  |   Simar   | prabsimar@gmail.com |  19 | Jamshedpur |
# | 5  |   Ankit   |   ankit@gmail.com   |  27 |  Banglore  |
# | 4  |   Saurav  |   sourav@gmail.com  |  32 |  Channai   |
# +----+-----------+---------------------+-----+------------+

# %%
# %%sql
# ALTER TABLE student
# ALTER COLUMN age TYPE SMALLINT;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from student;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# 6 rows affected.
# +----+-----------+---------------------+-----+------------+
# | id | full_name |        email        | age |    city    |
# +----+-----------+---------------------+-----+------------+
# | 2  |   Priya   |   priya@yahoo.com   |  30 |   Delhi    |
# | 3  |   Gaurav  |  gourav@hotmail.com |  25 |  Kolkata   |
# | 1  |   Rajesh  |   rajesh@gmail.com  |  26 |   Mumbai   |
# | 6  |   Simar   | prabsimar@gmail.com |  19 | Jamshedpur |
# | 5  |   Ankit   |   ankit@gmail.com   |  27 |  Banglore  |
# | 4  |   Saurav  |   sourav@gmail.com  |  32 |  Channai   |
# +----+-----------+---------------------+-----+------------+

# %%
# %%sql
# -- To add non-null constrain to city column
# ALTER TABLE student
# ALTER COLUMN city SET NOT NULL;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from student;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# 6 rows affected.
# +----+-----------+---------------------+-----+------------+
# | id | full_name |        email        | age |    city    |
# +----+-----------+---------------------+-----+------------+
# | 2  |   Priya   |   priya@yahoo.com   |  30 |   Delhi    |
# | 3  |   Gaurav  |  gourav@hotmail.com |  25 |  Kolkata   |
# | 1  |   Rajesh  |   rajesh@gmail.com  |  26 |   Mumbai   |
# | 6  |   Simar   | prabsimar@gmail.com |  19 | Jamshedpur |
# | 5  |   Ankit   |   ankit@gmail.com   |  27 |  Banglore  |
# | 4  |   Saurav  |   sourav@gmail.com  |  32 |  Channai   |
# +----+-----------+---------------------+-----+------------+

# %%
# %%sql
# -- Adding check constaint to age column
# ALTER TABLE student
# ADD CONSTRAINT age CHECK(age >= 18);
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from student;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# 6 rows affected.
# +----+-----------+---------------------+-----+------------+
# | id | full_name |        email        | age |    city    |
# +----+-----------+---------------------+-----+------------+
# | 2  |   Priya   |   priya@yahoo.com   |  30 |   Delhi    |
# | 3  |   Gaurav  |  gourav@hotmail.com |  25 |  Kolkata   |
# | 1  |   Rajesh  |   rajesh@gmail.com  |  26 |   Mumbai   |
# | 6  |   Simar   | prabsimar@gmail.com |  19 | Jamshedpur |
# | 5  |   Ankit   |   ankit@gmail.com   |  27 |  Banglore  |
# | 4  |   Saurav  |   sourav@gmail.com  |  32 |  Channai   |
# +----+-----------+---------------------+-----+------------+

# %%
# %%sql
# ALTER TABLE student
# DROP CONSTRAINT age;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# ++
# ||
# ++
# ++

# %%
# %%sql
# ALTER TABLE student
# ADD CONSTRAINT age CHECK(age >= 18);
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# ++
# ||
# ++
# ++

# %%
# %%sql
# INSERT INTO student (full_name, email, age, city)
# VALUES ('Vinod', 'vinodgmail.com', 60, 'Jamshedpur');
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# 1 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from student;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# 7 rows affected.
# +----+-----------+---------------------+-----+------------+
# | id | full_name |        email        | age |    city    |
# +----+-----------+---------------------+-----+------------+
# | 2  |   Priya   |   priya@yahoo.com   |  30 |   Delhi    |
# | 3  |   Gaurav  |  gourav@hotmail.com |  25 |  Kolkata   |
# | 1  |   Rajesh  |   rajesh@gmail.com  |  26 |   Mumbai   |
# | 6  |   Simar   | prabsimar@gmail.com |  19 | Jamshedpur |
# | 5  |   Ankit   |   ankit@gmail.com   |  27 |  Banglore  |
# | 4  |   Saurav  |   sourav@gmail.com  |  32 |  Channai   |
# | 7  |   Vinod   |    vinodgmail.com   |  60 | Jamshedpur |
# +----+-----------+---------------------+-----+------------+

# %%
# %%sql
# ALTER TABLE student
# RENAME TO customers;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from customers;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# 7 rows affected.
# +----+-----------+---------------------+-----+------------+
# | id | full_name |        email        | age |    city    |
# +----+-----------+---------------------+-----+------------+
# | 2  |   Priya   |   priya@yahoo.com   |  30 |   Delhi    |
# | 3  |   Gaurav  |  gourav@hotmail.com |  25 |  Kolkata   |
# | 1  |   Rajesh  |   rajesh@gmail.com  |  26 |   Mumbai   |
# | 6  |   Simar   | prabsimar@gmail.com |  19 | Jamshedpur |
# | 5  |   Ankit   |   ankit@gmail.com   |  27 |  Banglore  |
# | 4  |   Saurav  |   sourav@gmail.com  |  32 |  Channai   |
# | 7  |   Vinod   |    vinodgmail.com   |  60 | Jamshedpur |
# +----+-----------+---------------------+-----+------------+
