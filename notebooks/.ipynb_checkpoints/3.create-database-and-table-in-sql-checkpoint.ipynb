# %%
# %load_ext sql
# %sql postgresql://admin:admin@db:5432/testdb
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting to 'postgresql://admin:***@db:5432/testdb'

# %%
# %%sql
# CREATE DATABASE company;
# Out:
# Running query in 'postgresql://admin:***@db:5432/testdb'
# ++
# ||
# ++
# ++

# %%
# %load_ext sql
# %sql postgresql://admin:admin@db:5432/company
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting and switching to connection 'postgresql://admin:***@db:5432/company'

# %%
# %%sql
# CREATE TABLE employee(
#     id SERIAL primary key,
#     name VARCHAR(100) NOT NULL,
#     postiion VARCHAR(50), -- can be blank
#     department VARCHAR(50),
#     hire_date DATE,
#     salary NUMERIC(10, 2) -- 2 decimal places
# );
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT * FROM employee;
# Out:
# Running query in 'postgresql://admin:***@db:5432/company'
# +----+------+----------+------------+-----------+--------+
# | id | name | postiion | department | hire_date | salary |
# +----+------+----------+------------+-----------+--------+
# +----+------+----------+------------+-----------+--------+
