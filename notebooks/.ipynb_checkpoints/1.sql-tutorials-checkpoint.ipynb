# %%
# %load_ext sql
# %sql postgresql://admin:admin@db:5432/testdb
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting and switching to connection 'postgresql://admin:***@db:5432/testdb'

# %%
# %%sql
# CREATE DATABASE users;
# Out:
# Running query in 'postgresql://admin:***@db:5432/testdb'
# ++
# ||
# ++
# ++

# %% [markdown]
# Make sure you have admin privilege before creating any database. Once a database is created, you can check it in the list of databases with the following SQL command: SHOW DATABASES;

# %%
# %%sql
# SHOW DATABASES;

# %%
# %%sql
# DROP DATABASE users;
# -- DROP DATABASE xyz; -- does not exits
# Out:
# Running query in 'postgresql://admin:***@db:5432/testdb'
# ++
# ||
# ++
# ++

# %%
# %%sql
# CREATE TABLE users (
#     id int,
#     name varchar(255)
# );
# Out:
# Running query in 'postgresql://admin:***@db:5432/testdb'
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT * from users;
# Out:
# Running query in 'postgresql://admin:***@db:5432/testdb'
# +----+------+
# | id | name |
# +----+------+
# +----+------+
